# %% [markdown]
# <a href="https://colab.research.google.com/github/techspiration/PYTHON/blob/main/How_can_Tensorflow_be_used_with_abalone_dataset_to_build_a_sequential_model%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from keras import layers

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Now let’s load the data frame into the panda’s data frame.

# %%
df = pd.read_csv('/content/abalone (1).csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Here the ring’s feature is actually the age of the abalone. It can be calculated by adding 1.5 to the number of rings present in the abalone shell.

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# Let’s check which column of the dataset contains which type of data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# Checking some descriptive statistical measures of the dataset will help us to understand the distribution of the height and weight of an abalone.

# %%
df.describe().T
# Out:
#                  count      mean       std     min     25%     50%     75%  \
# Length          4177.0  0.523992  0.120093  0.0750  0.4500  0.5450   0.615
# Diameter        4177.0  0.407881  0.099240  0.0550  0.3500  0.4250   0.480
# Height          4177.0  0.139516  0.041827  0.0000  0.1150  0.1400   0.165
# Whole weight    4177.0  0.828742  0.490389  0.0020  0.4415  0.7995   1.153
# Shucked weight  4177.0  0.359367  0.221963  0.0010  0.1860  0.3360   0.502
# Viscera weight  4177.0  0.180594  0.109614  0.0005  0.0935  0.1710   0.253
# Shell weight    4177.0  0.238831  0.139203  0.0015  0.1300  0.2340   0.329
# Rings           4177.0  9.933684  3.224169  1.0000  8.0000  9.0000  11.000
#
#                     max
# Length           0.8150
# Diameter         0.6500
# Height           1.1300
# Whole weight     2.8255
# Shucked weight   1.4880
# Viscera weight   0.7600
# Shell weight     1.0050
# Rings           29.0000

# %% [markdown]
# **Exploratory Data Analysis**
# EDA is an approach to analyzing the data using visual techniques. It is used to discover trends, and patterns, or to check assumptions with the help of statistical summaries and graphical representations.

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# Now let’s check the distribution of the data in male, female and infant.

# %%
x = df['Sex'].value_counts()
labels = x.index
values = x.values
plt.pie(values,
        labels=labels,
        autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Here we can say that we have been provided with an equal amount of data for Male female and Infant abalone.

# %%
df.groupby('Sex').mean()
# Out:
#        Length  Diameter    Height  Whole weight  Shucked weight  \
# Sex
# F    0.579093  0.454732  0.158011      1.046532        0.446188
# I    0.427746  0.326494  0.107996      0.431363        0.191035
# M    0.561391  0.439287  0.151381      0.991459        0.432946
#
#      Viscera weight  Shell weight      Rings
# Sex
# F          0.230689      0.302010  11.129304
# I          0.092010      0.128182   7.890462
# M          0.215545      0.281969  10.705497

# %% [markdown]
# Here is an interesting observation that the life expectancy of the female abalone is higher than that of the male abalone. In the other features as well we can see that the height weight, as well as length in all the attributes of the numbers for female abalones, is on the higher sides.

# %%
features = df.loc[:, 'Length':'Shell weight'].columns
plt.subplots(figsize=(20, 10))
for i, feat in enumerate(features):
    plt.subplot(2, 4, i+1)
    sb.scatterplot(data=df, x=feat,
                   y='Rings', hue='Sex')
plt.show()

# %% [markdown]
# Observations from the above graph are as follows:
#
# A strong linear correlation between the age of the abalone and its height can be observed from the above graphs.
# Length and Diameter have the same kind of relation with age that is up to a certain age length increases and after that it became constant. A similar kind of relationship is present between the weight and the age feature.

# %%
plt.subplots(figsize=(20, 10))
for i, feat in enumerate(features):
    plt.subplot(2, 4, i+1)
    sb.violinplot(data=df, x=feat, hue='Sex')

plt.subplot(2, 4, 8)
sb.violinplot(data=df, x='Rings', hue='Sex')
plt.show()

# %% [markdown]
# Now we will separate the features and target variables and split them into training and validation data using which we will evaluate the performance of the model on the validation data.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# Before splitting the data, perform level encoding on the 'Sex' column
le = LabelEncoder ()
df['Sex_encoded'] = le.fit_transform(df['Sex'])  # Creates a new column 'Sex_encoded'

# Drop the original 'Sex' column
df = df.drop('Sex', axis=1)

# Now proceed with feature and target separation and data splitting
features = df.drop('Rings', axis=1)
target = df['Rings']

X_train, X_val,    Y_train, Y_val = train_test_split(features, target,
                                    test_size=0.2,
                                    random_state=22)

X_train.shape, X_val.shape
# Out:
# ((3341, 8), (836, 8))

# %% [markdown]
# **Model Architecture**
#
# We will implement a Sequential model which will contain the following parts:
#
# We will have two fully connected layers.
# We have included some BatchNormalization layers to enable stable and fast training and a Dropout layer before the final layer to avoid any possibility of overfitting.

# %%
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=[8]),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1, activation='relu')
])

model.compile(
    loss='mae',
    optimizer='adam',
    metrics=['mape']
)

# %% [markdown]
# While compiling a model we provide these three essential parameters:
#
# optimizer – This is the method that helps to optimize the cost function by using gradient descent.
# loss – The loss function by which we monitor whether the model is improving with training or not.
# metrics – This helps to evaluate the model by predicting the training and the validation data.
#
# ---

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 256)                 │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %% [markdown]
# Now we will train our model.

# %%
history = model.fit(X_train, Y_train,
                    epochs=50,
                    verbose=1,
                    batch_size=64,
                    validation_data=(X_val, Y_val))
# Out:
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 6.6869 - mape: 66.4185 - val_loss: 7.7568 - val_mape: 74.7498
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9017 - mape: 46.2105 - val_loss: 6.9616 - val_mape: 65.9395
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.7955 - mape: 44.9408 - val_loss: 6.4588 - val_mape: 60.5037
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7015 - mape: 44.2266 - val_loss: 5.6459 - val_mape: 51.8370
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4144 - mape: 40.6431 - val_loss: 2.9714 - val_mape: 26.5129
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6033 - mape: 32.6796 - val_loss: 2.5717 - val_mape: 29.2851
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8449 - mape: 26.8538 - val_loss: 2.5532 - val_mape: 30.1364
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5531 - mape: 24.3464 - val_loss: 2.5657 - val_mape: 29.3220
# ...

# %% [markdown]
# Let’s visualize the training and validation mae and mape with each epoch.

# %%
hist_df=pd.DataFrame(history.history)
hist_df.head()
# Out:
#        loss       mape  val_loss   val_mape
# 0  5.748583  56.058720  7.756819  74.749817
# 1  4.897871  45.943497  6.961593  65.939545
# 2  4.825489  45.751385  6.458822  60.503704
# 3  4.732945  44.329575  5.645931  51.837036
# 4  4.244538  38.940205  2.971364  26.512917

# %%
hist_df['loss'].plot()
hist_df['val_loss'].plot()
plt.title('Loss v/s Validation Loss')
plt.legend()
plt.show()

# %%
hist_df['mape'].plot()
hist_df['val_mape'].plot()
plt.title('MAPE v/s Validation MAPE')
plt.legend()
plt.show()

# %% [markdown]
# From the above two graphs, we can certainly say that the two(mae and mape) error values have decreased simultaneously and continuously. Also, the saturation has been achieved after 15 epochs only.
